# %% [markdown]
# # 11.2 SVM中的距离推导

# %% [markdown]
# ## 11.2.1 由二维距离扩展到n维空间

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 11.2.2对于两类任意一个y分别设为1或者-1，将常数都除向左侧

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 11.2.3 由于||w||d为常数，进一步改写形式Wd bd形式

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 11.2.4 中间向量右侧为0，左右都乘以||w||d，结果不变，可同样改写成Wd bd形式，最终再统一简化

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 11.2.5  对于任意向量，左边最后也都是1，转化为最小化向量的模，再进一步转化为(||w||)^2/2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 11.2.6 SVM的最优化是有条件的最优化问题
# - 最优化一个有条件的目标函数
# - 会用到拉普拉斯算子来进行优化

# %% [markdown]
# ![image.png](attachment:image.png)
