# %% [markdown]
# # 11.3 Soft Margin SVM 及 模型正则化

# %% [markdown]
# ## 11.3.1 Soft Margin SVM
# - Soft Margin SVM 目标是有一定的容错能力
# - 允许有一些点在两条支撑向量之间，每一对支撑向量都有一个η
# - 超参数C来调节

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 11.3.2 Soft Margin SVM的正则化
# - 通常也有L1和L2两种正则方式
# - L1正则中由于，η设定的就是大于0，因此不需要加绝对值
# - C是控制正则化的权重，即容错空间的大小
#     - C为0，则为Hard Margin SVM
#     - C越小，容错空间越大

# %% [markdown]
# ![image.png](attachment:image.png)
