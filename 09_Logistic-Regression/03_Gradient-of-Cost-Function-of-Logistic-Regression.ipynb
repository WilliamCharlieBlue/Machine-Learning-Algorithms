# %% [markdown]
# # 9.3 逻辑回归损失函数的梯度

# %% [markdown]
# ## 9.3.1 梯度的推导
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 9.3.2 梯度的向量化
# - 逻辑回归与线性回归的相似性
#     - 区别在仅在于预测值的不同，以及线性回归由于MSE评估(使用了2倍)
#     - 线性回归为X*θ
#     - 逻辑回归为σ(X*θ)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
