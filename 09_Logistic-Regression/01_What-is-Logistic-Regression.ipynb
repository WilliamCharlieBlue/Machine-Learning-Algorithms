# %% [markdown]
# # 9.1 什么是逻辑回归

# %% [markdown]
# ## 9.1.1 逻辑回归的简单说明
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 9.1.2 Sigmoid函数

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoid(t):
    return 1 / (1 + np.exp(-t))

# %%
x = np.linspace(-10, 10, 500)
y = sigmoid(x)

plt.plot(x, y)
plt.show()
