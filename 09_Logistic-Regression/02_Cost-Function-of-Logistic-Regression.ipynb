# %% [markdown]
# # 9.2 逻辑回归的损失函数

# %% [markdown]
# ### 9.2.1 逻辑回归的结果分类
#     - 预测的p大于等于0.5，判定为1；反之判定为0
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 9.2.2 惩罚函数的图像展示
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 9.2.3 惩罚函数的公式化
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 9.2.4 逻辑回归使用的损失函数
#     - 没有公式解，可用梯度下降法来求解
#     - J(θ)为凸函数，没有局部最优解，全局只有一个最优解
#     - Xb 和 y 为已知值，θ是未知的
# ![image.png](attachment:image.png)
