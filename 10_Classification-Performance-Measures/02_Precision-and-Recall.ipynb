# %% [markdown]
# # 10.2 精准率和召回率

# %% [markdown]
# ## 10.2.1 通常在有偏的数据中，把1作为关注的对象
# - 精准率 precision
#     - 精准率指的是，预测值为1中预测正确的比例
# - 召回率 recall
#     - 召回率指的是，真实值为1中预测正确的比例

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 10.2.2 使用精准率和召回率，对极度偏斜的数据不会误判

# %% [markdown]
# ![image.png](attachment:image.png)
